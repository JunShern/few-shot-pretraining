# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
from scavenger import criterion

np.random.seed(0) # Also sets seed for pandas
sns.set_theme(style="whitegrid")

# %% [markdown]
# # Get dataset lengths

# %%
from scavenger.reader import C4Reader, PileReader, DataSplit

c4_reader = C4Reader(data_root="/data/c4", data_split=DataSplit.VAL)
print("Length of C4 dataset:", len(c4_reader))
# Out:
# Length of C4 dataset: 364608

# %%
pile_reader = PileReader(data_root="/data/pile", data_split=DataSplit.VAL)
print("Length of Pile dataset:", len(pile_reader))
# Out:
# Length of Pile dataset: 214670

# %% [markdown]
# # The Pile

# %%
data_dir = "./output/pile"
data_path = Path(data_dir) / "table.csv"

# %%
df = pd.read_csv(str(data_path))
df.head(10)
# Out:
#    doc_id  AllDocuments  Domain  QuestionAnswerStrings  FullyStructured  \
# 0       0          True   False                  False            False
# 1       1          True   False                  False            False
# 2       2          True   False                  False            False
# 3       3          True   False                  False            False
# 4       4          True   False                  False            False
# 5       5          True   False                   True            False
# 6       6          True   False                  False            False
# 7       7          True   False                  False            False
# 8       8          True   False                   True            False
# 9       9          True   False                  False            False
#
#    ExamStrings  QuestionStrings  ExamplesStrings  NewlineOccurrence  \
# 0        False             True            False               True
# 1        False            False            False               True
# 2        False            False            False              False
# 3        False            False            False               True
# 4        False            False            False              False
# 5        False             True            False               True
# 6        False            False            False              False
# 7        False            False            False              False
# 8        False             True            False               True
# 9        False            False            False              False
#
#                                              preview
# 0  Catalonia election: Puigdemont calls for talks...
# 1  Wirex, a prominent UK’s FCA supported cryptocu...
# 2  Effect of sleep quality on memory, executive f...
# 3  ### Solution for "Download of Code Without Int...
# 4  Fluorescent labeling of both GABAergic and gly...
# 5  Q:How to avoid anti-clockwise rotation animati...
# 6  Carotid endarterectomy: operative risks, recur...
# 7  Regulation of the anaerobic metabolism in Baci...
# 8  Q:ReCAPTCHA v3 is not working in a Shopify Con...
# 9  Early and long-term outcomes after manual and ...

# %%
df_criteria = df.select_dtypes(include=bool)
# Get counts for each criterion
criteria_counts = df_criteria.apply(pd.value_counts).loc[True]
criteria_counts.fillna(0, inplace=True)
criteria_counts.sort_values(ascending=False, inplace=True)
df_counts = pd.DataFrame({
    "criteria": criteria_counts.index,
    "counts": criteria_counts.values,
})

display(df_counts)
ax = sns.barplot(x="counts", y="criteria", data=df_counts[df_counts.criteria != "AllDocuments"])
# Out:
#                 criteria    counts
# 0           AllDocuments  214670.0
# 1      NewlineOccurrence  100685.0
# 2        QuestionStrings   40697.0
# 3  QuestionAnswerStrings   33190.0
# 4        FullyStructured    2388.0
# 5            ExamStrings    1842.0
# 6        ExamplesStrings     111.0
# 7                 Domain       0.0

# %% [markdown]
# # C4

# %%
data_dir = "./output/c4"
data_path = Path(data_dir) / "table.csv"

# %%
df = pd.read_csv(str(data_path))
df.head(10)
# Out:
#    doc_id  AllDocuments  Domain  QuestionAnswerStrings  FullyStructured  \
# 0       0          True   False                  False            False
# 1       1          True   False                  False            False
# 2       2          True   False                  False            False
# 3       3          True   False                  False            False
# 4       4          True   False                  False            False
# 5       5          True   False                  False            False
# 6       6          True   False                  False            False
# 7       7          True   False                  False            False
# 8       8          True   False                  False            False
# 9       9          True   False                  False            False
#
#    ExamStrings  QuestionStrings  ExamplesStrings  NewlineOccurrence  \
# 0        False            False            False              False
# 1        False             True            False              False
# 2        False            False            False              False
# 3        False             True            False              False
# 4        False            False            False              False
# 5        False            False            False              False
# 6        False             True            False              False
# 7        False            False            False              False
# 8        False            False            False              False
# 9        False            False            False              False
#
#                                              preview
# 0  The woman who died after falling from a bridge...
# 1  messaging system designed as a plugin-based sy...
# 2  CHARLES H. MEISNER, one of the prosperous and ...
# 3  EVER WONDER WHY SOME PEOPLE CAN WORK NIGHTS AN...
# 4  Conduct effective product control and valuatio...
# 5  Stayed here about four years ago and they help...
# 6  It’s the end of the world,” said the caterpill...
# 7  Fasnet 2015: Spindrift & Prince de Bretagne , ...
# 8  As the nation’s largest no-reserve internet au...
# 9  Stretch Therapy (ST) is a comprehensive system...

# %%
df_criteria = df.select_dtypes(include=bool)
# Get counts for each criterion
criteria_counts = df_criteria.apply(pd.value_counts).loc[True]
criteria_counts.fillna(0, inplace=True)
criteria_counts.sort_values(ascending=False, inplace=True)
df_counts = pd.DataFrame({
    "criteria": criteria_counts.index,
    "counts": criteria_counts.values,
})

display(df_counts)
ax = sns.barplot(x="counts", y="criteria", data=df_counts[df_counts.criteria != "AllDocuments"])
# Out:
#                 criteria    counts
# 0           AllDocuments  364608.0
# 1        QuestionStrings   56990.0
# 2      NewlineOccurrence   19263.0
# 3  QuestionAnswerStrings    3634.0
# 4            ExamStrings    2226.0
# 5                 Domain     729.0
# 6        ExamplesStrings     170.0
# 7        FullyStructured     127.0
